# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('hv_convergence.csv')
data['0'].plot(figsize=(10,8))
plt.show()

# %%
data
# Out:
#                0
# 0    1320.800147
# 1    1324.615670
# 2    1327.196753
# 3    1327.844343
# 4    1328.646553
# ..           ...
# 245  1330.175274
# 246  1330.049751
# 247  1330.065039
# 248  1329.936211
# 249  1330.204654
#
# [250 rows x 1 columns]

# %%
import numpy as np

# %%
# Out:
# [0.8510534414941064,
#  0.8517489919735278,
#  0.20786796537587482,
#  0.766964776635823]

# %%
dimension = 3
lista = [np.random.rand() for i in range(dimension)]
while(sum(lista) != 1):
    lista = [np.random.rand() for i in range(dimension)]
    print(lista)
# Out:
# [0.42801094788632643, 0.5409245795902172, 0.149302349688625]
# [0.8667648550981787, 0.07486120485788772, 0.34445418987668597]
# [0.7148437908225491, 0.9745485310945464, 0.4017724990138114]
# [0.18482227188279787, 0.5923365477299208, 0.07175964479652486]
# [0.5371605745778195, 0.5646633090190373, 0.6376714939303643]
# [0.5326299553924718, 0.5430745758994272, 0.26616461789161205]
# [0.10223781886867112, 0.03241110986832374, 0.024327803124496228]
# [0.27169722241426153, 0.003397454182823445, 0.3339312843019009]
# [0.871792714164593, 0.9014202327105907, 0.06782705279658574]
# [0.26486249055512945, 0.9169133881186964, 0.006125773412184676]
# [0.7680416116242142, 0.9158511035032796, 0.9920014997518887]
# [0.08628474593966473, 0.5847518946908862, 0.017703508672779922]
# [0.8044003120550157, 0.08543441545156638, 0.6163512091171823]
# [0.23556531148837323, 0.7784171359722626, 0.7692655329886325]
# [0.9322982405160936, 0.3653141271460948, 0.04971593145967401]
# ...

# %%
dimension = 3
weights = np.random.rand(dimension)
weights
# Out:
# array([0.46269742, 0.88237568, 0.16265343])

# %%
weights/sum(weights)
# Out:
# 1.0000000000000002
