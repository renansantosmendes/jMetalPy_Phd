# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('hv_convergence.csv')
data['0'].plot(figsize=(6,4))
plt.show()

# %%
data
# Out:
#               0
# 0   1318.445660
# 1   1319.340696
# 2   1324.635855
# 3   1325.264681
# 4   1327.369423
# 5   1329.045582
# 6   1329.473010
# 7   1329.713714
# 8   1329.885579
# 9   1330.003430
# 10  1330.017384
# 11  1330.074618
# 12  1330.104177
# 13  1330.092491
# 14  1330.137983
# 15  1330.164398
# 16  1330.177805
# 17  1330.187705
# 18  1330.185320
# 19  1330.199021
# 20  1330.192945
# 21  1330.210806
# 22  1330.215664
# 23  1330.233968
# 24  1330.243627
# 25  1330.247840
# 26  1330.253417
# 27  1330.264855
# 28  1330.167638
# 29  1330.172652
# 30  1330.175436
# 31  1330.176783
# 32  1330.267203
# 33  1330.270178
# 34  1330.286986
# 35  1330.293412
# 36  1330.292008
# 37  1330.291314
# 38  1330.293849
# 39  1330.295527
